# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("C:\Data Science\Data Trained\Abalone\project abalone.csv")

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
df.shape
# Out:
# (4177, 9)

# %% [markdown]
# There are 4177 rows and 9 columns

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %% [markdown]
# Only sex column is an object

# %%
df["Sex"].unique()
# Out:
# array(['M', 'F', 'I'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# There are no missing values in any column

# %% [markdown]
# # Checking for Outliers:

# %%
df.boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# There are Outliers in every column

# %% [markdown]
# # Checking for Count of Region:

# %%
fig, ax=plt.subplots(figsize=(22,7))
sn.countplot(x="Sex", data=df)
print(df['Sex'].value_counts())
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %% [markdown]
# There the values are almost spread equally in Sex column.

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %% [markdown]
# # Univariate Analysis:

# %%
sn.distplot(df["Length"])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %%
df["Length"].mean()
# Out:
# 0.5239920995930094

# %%
df["Length"].median()
# Out:
# 0.545

# %% [markdown]
# Left Skewed distribution

# %%
sn.distplot(df["Diameter"])
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Density'>

# %%
df["Diameter"].mean()
# Out:
# 0.40788125448886764

# %%
df["Diameter"].median()
# Out:
# 0.425

# %% [markdown]
# Left Skewed distribution

# %%
sn.distplot(df["Height"])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
df["Height"].mean()
# Out:
# 0.13951639932966242

# %%
df["Height"].median()
# Out:
# 0.14

# %% [markdown]
# Right Skewed distribution

# %%
sn.distplot(df["Whole weight"])
# Out:
# <AxesSubplot:xlabel='Whole weight', ylabel='Density'>

# %%
df["Whole weight"].mean()
# Out:
# 0.8287421594445774

# %%
df["Whole weight"].median()
# Out:
# 0.7995

# %% [markdown]
# Right Skewed distribution

# %%
sn.distplot(df["Shucked weight"])
# Out:
# <AxesSubplot:xlabel='Shucked weight', ylabel='Density'>

# %%
df["Shucked weight"].mean()
# Out:
# 0.35936748862820206

# %%
df["Shucked weight"].median()
# Out:
# 0.336

# %% [markdown]
# Right Skewed distribution

# %%
sn.distplot(df["Viscera weight"])
# Out:
# <AxesSubplot:xlabel='Viscera weight', ylabel='Density'>

# %%
df["Viscera weight"].mean()
# Out:
# 0.1805936078525257

# %%
df["Viscera weight"].median()
# Out:
# 0.171

# %% [markdown]
# Right Skewed distribution

# %%
sn.distplot(df["Shell weight"])
# Out:
# <AxesSubplot:xlabel='Shell weight', ylabel='Density'>

# %%
df["Shell weight"].mean()
# Out:
# 0.23883085946851804

# %%
df["Shell weight"].median()
# Out:
# 0.234

# %% [markdown]
# Right Skewed distribution

# %%
sn.distplot(df["Rings"])
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Density'>

# %%
df["Rings"].mean()
# Out:
# 9.933684462532918

# %%
df["Rings"].median()
# Out:
# 9.0

# %% [markdown]
# Right Skewed distribution

# %% [markdown]
# # Bivariate Analysis:

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
col=[ 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
       'Viscera weight', 'Shell weight']

for i in col:

    figure = plt.figure
    ax = plt.gca()
    sn.scatterplot(df["Sex"],df[i],hue=df["Rings"])
    plt.legend()
    plt.show()

# %% [markdown]
# No recognizable pattern

# %%
col=[ 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
       'Viscera weight', 'Shell weight']

for i in col:

    figure = plt.figure
    ax = plt.gca()
    sn.scatterplot(df["Length"],df[i],hue=df["Rings"])
    plt.legend()
    plt.show()

# %% [markdown]
# Diameter and Height increase lineraly with Length, and also rings increases when all three increases in value

# %% [markdown]
# Whole weight, Shucked weight,Viscera weight and Shell weight increase exponentially with the increase in length, and also rings increases when all five increases in value

# %%
col=[  'Height', 'Whole weight', 'Shucked weight',
       'Viscera weight', 'Shell weight']

for i in col:

    figure = plt.figure
    ax = plt.gca()
    sn.scatterplot(df["Diameter"],df[i],hue=df["Rings"])
    plt.legend()
    plt.show()

# %% [markdown]
# Diameter  increase linearly with Height, and also rings increase when both increases in value

# %% [markdown]
# Whole weight, Shucked weight,Viscera weight and Shell weight increase exponentially with the increase in Diameter, and also rings increases when all five increases in value

# %%
col=[   'Whole weight', 'Shucked weight',
       'Viscera weight', 'Shell weight']

for i in col:

    figure = plt.figure
    ax = plt.gca()
    sn.scatterplot(df["Height"],df[i],hue=df["Rings"])
    plt.legend()
    plt.show()

# %% [markdown]
# Whole weight, Shucked weight,Viscera weight and Shell weight increase linearly with the increase in Height, and also rings increases when all five increases in value

# %%
col=[    'Shucked weight',
       'Viscera weight', 'Shell weight']

for i in col:

    figure = plt.figure
    ax = plt.gca()
    sn.scatterplot(df["Whole weight"],df[i],hue=df["Rings"])
    plt.legend()
    plt.show()

# %% [markdown]
# Shucked weight,Viscera weight and Shell weight increase linearly with the increase in Whole weight, and also rings increases when all four increases in value

# %%
col=[    
       'Viscera weight', 'Shell weight']

for i in col:

    figure = plt.figure
    ax = plt.gca()
    sn.scatterplot(df["Shucked weight"],df[i],hue=df["Rings"])
    plt.legend()
    plt.show()

# %% [markdown]
# Viscera weight and Shell weight increase linearly with the increase in Shucked weight, and also rings increases when all three increases in value

# %%
col=[    
        'Shell weight']

for i in col:

    figure = plt.figure
    ax = plt.gca()
    sn.scatterplot(df["Viscera weight"],df[i],hue=df["Rings"])
    plt.legend()
    plt.show()

# %% [markdown]
# Shell weight increase linearly with the increase in Shucked weight, and also rings increases when both increases in value

# %% [markdown]
# # Label Encoding:

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()

# %%
df["Sex"]=LE.fit_transform(df["Sex"])

# %% [markdown]
# # Corelation:

# %%
cor=df.corr()

# %%
sn.heatmap(cor,annot=True, linewidths=1,linecolor='green')
# Out:
# <AxesSubplot:>

# %%
cor_matrix=df.corr()
cor_matrix["Rings"].sort_values(ascending=False)
# Out:
# Rings             1.000000
# Shell weight      0.627574
# Diameter          0.574660
# Height            0.557467
# Length            0.556720
# Whole weight      0.540390
# Viscera weight    0.503819
# Shucked weight    0.420884
# Sex              -0.034627
# Name: Rings, dtype: float64

# %% [markdown]
# Looks all the columns except sex has good corelation with the target vaiable Rings

# %% [markdown]
# # Outlier removal:

# %% [markdown]
# Zscore:

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df.drop(["Sex"], axis=1)))

# %%
z_df=df[(z<3).all(axis=1)]

# %%
z_df.shape
# Out:
# (4027, 9)

# %%
df.shape
# Out:
# (4177, 9)

# %%
(1-(4027/4177))*100
# Out:
# 3.59109408666507

# %% [markdown]
# The data loss is 3.59 percent

# %%
new_df=z_df

# %%
new_df.describe()
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4027.000000  4027.000000  4027.000000  4027.000000   4027.000000
# mean      1.051403     0.520987     0.405300     0.138002      0.802805
# std       0.818071     0.115910     0.095903     0.036878      0.456192
# min       0.000000     0.165000     0.115000     0.015000      0.014500
# 25%       0.000000     0.450000     0.345000     0.115000      0.438000
# 50%       1.000000     0.540000     0.420000     0.140000      0.783000
# 75%       2.000000     0.610000     0.480000     0.165000      1.131250
# max       2.000000     0.760000     0.605000     0.250000      2.238500
#
#        Shucked weight  Viscera weight  Shell weight        Rings
# count     4027.000000     4027.000000   4027.000000  4027.000000
# mean         0.349099        0.175718      0.230676     9.738763
# std          0.206406        0.103350      0.127939     2.864691
# ...

# %% [markdown]
# # Skewness:

# %%
new_df.skew()
# Out:
# Sex              -0.094886
# Length           -0.623076
# Diameter         -0.598650
# Height           -0.244251
# Whole weight      0.334204
# Shucked weight    0.458295
# Viscera weight    0.437116
# Shell weight      0.349471
# Rings             0.725464
# dtype: float64

# %% [markdown]
# Need to apply skewness transformation on Length, diameter and Rings

# %%
np.log(new_df["Length"]).skew()
# Out:
# -1.3232170902742664

# %%
np.sqrt(new_df["Length"]).skew()
# Out:
# -0.9395514896272457

# %%
np.cbrt(new_df["Length"]).skew()
# Out:
# -1.0588734884680484

# %%
np.log1p(new_df["Length"]).skew()
# Out:
# -0.8061358771032854

# %% [markdown]
# Since the skewness increases upon transformation, the skewness of Length is left as it is

# %%
np.log(new_df["Diameter"]).skew()
# Out:
# -1.3294312152530998

# %%
np.sqrt(new_df["Diameter"]).skew()
# Out:
# -0.9272240208062581

# %%
np.cbrt(new_df["Diameter"]).skew()
# Out:
# -1.051805916914861

# %%
np.log1p(new_df["Diameter"]).skew()
# Out:
# -0.7551573910248114

# %% [markdown]
# Since the skewness increases upon transformation, the skewness of Diameter is left as it is

# %%
np.log(new_df["Rings"]).skew()
# Out:
# -0.2747447605759774

# %%
new_df["Rings"]=np.log(new_df["Rings"])

# %% [markdown]
# Log transformed the Rings column

# %%
new_df.skew()
# Out:
# Sex              -0.094886
# Length           -0.623076
# Diameter         -0.598650
# Height           -0.244251
# Whole weight      0.334204
# Shucked weight    0.458295
# Viscera weight    0.437116
# Shell weight      0.349471
# Rings            -0.274745
# dtype: float64

# %% [markdown]
# # Separating Target and Independent variables

# %%
x=new_df.drop(["Rings"],axis=1)
y=new_df["Rings"]

# %% [markdown]
# # Best Random State:

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
from sklearn.linear_model import LinearRegression
mod=LinearRegression()
maxAccu1=0
maxRS1=0
maxAccu2=0
maxRS2=0
for i in range(0,200):
    x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=.30, random_state=i)
    mod.fit(x_train,y_train)
    pred_train=mod.predict(x_train)
    pred_test=mod.predict(x_test)
    acc1=r2_score(y_train,pred_train)
    acc2=r2_score(y_test,pred_test)
    print(f"At Random state {i}, the training accuracy is: {r2_score(y_train,pred_train)}")
    print(f"At Random state {i}, the testing accuracy is: {r2_score(y_test,pred_test)}")
    print("\n")
    if acc1>maxAccu1:
        maxAccu1=acc1
        maxRS1=i
        
    if acc2>maxAccu2:
        maxAccu2=acc2
        maxRS2=i
# Out:
# At Random state 0, the training accuracy is: 0.5828778963038344
# At Random state 0, the testing accuracy is: 0.5413397836641651
#
#
# At Random state 1, the training accuracy is: 0.5758053503857216
# At Random state 1, the testing accuracy is: 0.5544986052365779
#
#
# At Random state 2, the training accuracy is: 0.5771314718603449
# At Random state 2, the testing accuracy is: 0.5559473835749142
#
#
# At Random state 3, the training accuracy is: 0.5741260809543579
# At Random state 3, the testing accuracy is: 0.5614370589261182
#
#
# At Random state 4, the training accuracy is: 0.5673216092965727
# At Random state 4, the testing accuracy is: 0.5781725148375307
#
#
# At Random state 5, the training accuracy is: 0.5800250379898539
# At Random state 5, the testing accuracy is: 0.5475205777944943
#
#
# At Random state 6, the training accuracy is: 0.5722854330215339
# At Random state 6, the testing accuracy is: 0.5659325053137678
#
#
# ...

# %%
print("Best train accuracy is",maxAccu1,"on Random_state",maxRS1)
print("\n")
print("Best test accuracy is",maxAccu2,"on Random_state",maxRS2)
# Out:
# Best train accuracy is 0.5863582404966653 on Random_state 19
#
#
# Best test accuracy is 0.6053072046889758 on Random_state 82

# %% [markdown]
# # Train and Test Split:

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=.30, random_state=82)

# %% [markdown]
# # Linear Regression:

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_test=LR.predict(x_test)

print(r2_score(y_test,pred_test))
# Out:
# 0.6053072046889758

# %% [markdown]
# # Decision Tree Regression:

# %%
from sklearn.tree import DecisionTreeRegressor

DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
pred_test=DTR.predict(x_test)

print(r2_score(y_test,pred_test))
# Out:
# 0.3483069543319073

# %% [markdown]
# # RandomForestRegressor:

# %%
from sklearn.ensemble import RandomForestRegressor
RFR= RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_test=RFR.predict(x_test)

print(r2_score(y_test,pred_test))
# Out:
# 0.6458065645320537

# %% [markdown]
# # SupportVectorRegressor:

# %%
from sklearn.svm import SVR
SV= SVR()
SV.fit(x_train,y_train)
pred_test=SV.predict(x_test)

print(r2_score(y_test,pred_test))
# Out:
# 0.653691534852349

# %% [markdown]
# # LinearSVR:

# %%
from sklearn.svm import LinearSVR
LSV= LinearSVR()
LSV.fit(x_train,y_train)
pred_test=LSV.predict(x_test)

print(r2_score(y_test,pred_test))
# Out:
# 0.5909734391420824

# %% [markdown]
# # AdaBoostRegressor:

# %%
from sklearn.ensemble import AdaBoostRegressor
ADR= AdaBoostRegressor()
ADR.fit(x_train,y_train)
pred_test=ADR.predict(x_test)

print(r2_score(y_test,pred_test))
# Out:
# 0.5653132288249261

# %% [markdown]
# # BaggingRegressor:

# %%
from sklearn.ensemble import BaggingRegressor
BR= BaggingRegressor()
BR.fit(x_train,y_train)
pred_test=BR.predict(x_test)

print(r2_score(y_test,pred_test))
# Out:
# 0.6196374938930955

# %% [markdown]
# # ExtraTreesRegressor:

# %%
from sklearn.ensemble import ExtraTreesRegressor
ETR= ExtraTreesRegressor()
ETR.fit(x_train,y_train)
pred_test=ETR.predict(x_test)

print(r2_score(y_test,pred_test))
# Out:
# 0.6324323025293481

# %% [markdown]
# # GradientBoostingRegressor:

# %%
from sklearn.ensemble import GradientBoostingRegressor
GBR= GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_test=GBR.predict(x_test)

print(r2_score(y_test,pred_test))
# Out:
# 0.6561627418972431

# %% [markdown]
# # PLSRegression:

# %%
from sklearn.cross_decomposition import PLSRegression
PLSR=PLSRegression()
PLSR.fit(x_train,y_train)
pred_test=PLSR.predict(x_test)

print(r2_score(y_test,pred_test))
# Out:
# 0.5763476892524011

# %% [markdown]
# # SGDRegressor:

# %%
from sklearn.linear_model import SGDRegressor
SGDR=SGDRegressor()
SGDR.fit(x_train,y_train)
pred_test=SGDR.predict(x_test)

print(r2_score(y_test,pred_test))
# Out:
# 0.4626230121383784

# %% [markdown]
# # ARDRegression:

# %%
from sklearn.linear_model import ARDRegression
ARDR=ARDRegression()
ARDR.fit(x_train,y_train)
pred_test=ARDR.predict(x_test)

print(r2_score(y_test,pred_test))
# Out:
# 0.6043449821638507

# %% [markdown]
# # BayesianRidge:

# %%
from sklearn.linear_model import BayesianRidge
BAYR=BayesianRidge()
BAYR.fit(x_train,y_train)
pred_test=BAYR.predict(x_test)

print(r2_score(y_test,pred_test))
# Out:
# 0.6051654225466765

# %% [markdown]
# # HuberRegressor:

# %%
from sklearn.linear_model import HuberRegressor
HR=HuberRegressor()
HR.fit(x_train,y_train)
pred_test=HR.predict(x_test)

print(r2_score(y_test,pred_test))
# Out:
# 0.6011584348048533

# %% [markdown]
# # TheilSenRegressor:

# %%
from sklearn.linear_model import TheilSenRegressor
TR=TheilSenRegressor()
TR.fit(x_train,y_train)
pred_test=TR.predict(x_test)

print(r2_score(y_test,pred_test))
# Out:
# 0.5995372302360096

# %% [markdown]
# # Cross Validation Score:

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(LR,x,y,cv=5).mean())
# Out:
# 0.504063197963557

# %%
(0.6053072046889758-0.504063197963557)*100
# Out:
# 10.124400672541878

# %%
print(cross_val_score(DTR,x,y,cv=5).mean())
# Out:
# 0.2063741938887682

# %%
(0.3483069543319073-0.2063741938887682)*100
# Out:
# 14.193276044313908

# %%
print(cross_val_score(RFR,x,y,cv=5).mean())
# Out:
# 0.5634090918110137

# %%
(0.6458065645320537-0.5634090918110137)*100
# Out:
# 8.239747272103992

# %%
print(cross_val_score(SV,x,y,cv=5).mean())
# Out:
# 0.5874433890911664

# %%
(0.653691534852349-0.5874433890911664)*100
# Out:
# 6.624814576118254

# %%
print(cross_val_score(LSV,x,y,cv=5).mean())
# Out:
# 0.49851805168051316

# %%
(0.5909734391420824-0.49851805168051316)*100
# Out:
# 9.245538746156928

# %%
print(cross_val_score(ADR,x,y,cv=5).mean())
# Out:
# 0.4354163519436298

# %%
(0.5653132288249261-0.4354163519436298)*100
# Out:
# 12.989687688129624

# %%
print(cross_val_score(BR,x,y,cv=5).mean())
# Out:
# 0.524047709522837

# %%
(0.6196374938930955-0.524047709522837)*100
# Out:
# 9.558978437025855

# %%
print(cross_val_score(ETR,x,y,cv=5).mean())
# Out:
# 0.5642306100825785

# %%
(0.6324323025293481-0.5642306100825785)*100
# Out:
# 6.820169244676966

# %%
print(cross_val_score(GBR,x,y,cv=5).mean())
# Out:
# 0.5780465570939881

# %%
(0.6561627418972431-0.5780465570939881)*100
# Out:
# 7.8116184803254995

# %%
print(cross_val_score(PLSR,x,y,cv=5).mean())
# Out:
# 0.47799614782784544

# %%
(0.5763476892524011-0.47799614782784544)*100
# Out:
# 9.835154142455565

# %%
print(cross_val_score(SGDR,x,y,cv=5).mean())
# Out:
# 0.33808714223470365

# %%
(0.4626230121383784-0.33808714223470365)*100
# Out:
# 12.453586990367477

# %%
print(cross_val_score(ARDR,x,y,cv=5).mean())
# Out:
# 0.5035865338787938

# %%
(0.6043449821638507-0.5035865338787938)*100
# Out:
# 10.075844828505687

# %%
print(cross_val_score(BAYR,x,y,cv=5).mean())
# Out:
# 0.5040288919848683

# %%
(0.6051654225466765-0.5040288919848683)*100
# Out:
# 10.113653056180816

# %%
print(cross_val_score(HR,x,y,cv=5).mean())
# Out:
# 0.5026370003823439

# %%
(0.6011584348048533-0.5026370003823439)*100
# Out:
# 9.852143442250938

# %%
print(cross_val_score(TR,x,y,cv=5).mean())
# Out:
# 0.48319536905630595

# %%
(0.5995372302360096-0.48319536905630595)*100
# Out:
# 11.634186117970364

# %% [markdown]
# Since SupportVectorRegressor, ExtraTreesRegressor and GradientBoostingRegressor has the least difference between accuracy and cross validation score, need to check for evaluation metrics

# %%
import math
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %% [markdown]
# SupportVectorRegressor:

# %%
SV= SVR()
SV.fit(x_train,y_train)
pred_test=SV.predict(x_test)
print("MSE:",mean_squared_error(y_test,pred_test))
print("RMSE:",math.sqrt(mean_squared_error(y_test,pred_test)))
print("MAE:",mean_absolute_error(y_test,pred_test))
# Out:
# MSE: 0.03254022818601213
# RMSE: 0.1803891021819559
# MAE: 0.1390018242595068

# %% [markdown]
# ExtraTreesRegressor:

# %%
ETR= ExtraTreesRegressor()
ETR.fit(x_train,y_train)
pred_test=ETR.predict(x_test)
print("MSE:",mean_squared_error(y_test,pred_test))
print("RMSE:",math.sqrt(mean_squared_error(y_test,pred_test)))
print("MAE:",mean_absolute_error(y_test,pred_test))
# Out:
# MSE: 0.03450157305854056
# RMSE: 0.18574599069304445
# MAE: 0.14405007187910338

# %% [markdown]
# GradientBoostingRegressor:

# %%
GBR= GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_test=GBR.predict(x_test)
print("MSE:",mean_squared_error(y_test,pred_test))
print("RMSE:",math.sqrt(mean_squared_error(y_test,pred_test)))
print("MAE:",mean_absolute_error(y_test,pred_test))
# Out:
# MSE: 0.032303709942020795
# RMSE: 0.17973232859455418
# MAE: 0.13834304140238649

# %% [markdown]
# Since GradientBoostingRegressor has a better edge in terms of evaluation metrics compared to other models, we choose GradientBoostingRegressor as our final model

# %% [markdown]
# # Hyper Parameter Tuning:

# %%
parameter = { 


    "min_samples_split": np.arange(2,10),
    
    'criterion': ["friedman_mse","mse", "mae"],
    
    'max_features' :["auto", "sqrt", "log2"]}

# %%
from sklearn.model_selection import GridSearchCV
GV=GridSearchCV(GradientBoostingRegressor(),parameter,cv=5)
GV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['friedman_mse', 'mse', 'mae'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': array([2, 3, 4, 5, 6, 7, 8, 9])})

# %%
GV.best_params_
# Out:
# {'criterion': 'mse', 'max_features': 'auto', 'min_samples_split': 4}

# %% [markdown]
# # Finalizing the Model:

# %%
Final_mod=GradientBoostingRegressor(criterion= 'friedman_mse',
 max_features= 'auto')

# %%
Final_mod.fit(x_train,y_train)
final_pred=Final_mod.predict(x_test)
final_acc=r2_score(y_test,final_pred)

# %%
print(final_acc*100)
# Out:
# 65.64788801884366

# %%
print(cross_val_score(Final_mod,x,y,cv=5).mean())
# Out:
# 0.5781471485191781

# %% [markdown]
# The accuracy and the cross validation have not increased significantly even with hyper parameter tuning

# %%
import pickle
filename="WHR.pk1"
pickle.dump(Final_mod,open(filename,"wb"))

# %% [markdown]
# # Conclusion:

# %%
loaded_model=pickle.load(open("WHR.pk1","rb"))
result=loaded_model.score(x_test, y_test)
print(result)
# Out:
# 0.6564788801884366

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["Predicted", "Original"])
conclusion
# Out:
#                0         1         2         3         4         5     \
# Predicted  2.421975  2.313661  2.359436  2.325286  2.147364  1.984465
# Original   2.397895  2.397895  2.302585  2.302585  2.397895  2.079442
#
#                6         7         8         9     ...      1199      1200  \
# Predicted  2.449172  1.693683  2.366966  2.314438  ...  2.177210  2.419407
# Original   2.302585  1.791759  2.197225  2.079442  ...  2.079442  2.302585
#
#                1201      1202      1203      1204      1205      1206  \
# Predicted  2.338868  2.203180  1.448317  2.330381  2.498037  2.365331
# Original   2.302585  2.397895  1.386294  2.197225  2.197225  2.397895
#
#                1207      1208
# Predicted  1.416417  1.727556
# Original   1.386294  1.609438
#
# [2 rows x 1209 columns]
